# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Tugrul Demirbas
# Logistics Analyst II

# %% [markdown]
# ##### I am interested in data science because data analysis in logistic operations is important than ever.

# %% [markdown]
# ### The following will calculate the age of a customer.

# %%
birth_year= input("Enter your birth year:  ")
age= 2022-int(birth_year)
print("Age: ",age)
# Out:
# Enter your birth year:  1981
# Age:  41

# %% [markdown]
# 1. **IBM provides valuable resourses for coding: https://cloud.ibm.com/**
# 2. - [x] *One should learn data analysis for efficiency.*
# 3. - [ ]~~Coding is inevitable to do data anaylsis.~~
# 4. > This is a blocked quote: "Nothing is impossible!"
# 5. |Name|Surname|Age|
# |------|------|------|
# |John     |Smith     |35     |
# |Maria     |Clay     |45     |
# 6. <span style="blue">Thank you for reading and evaluating my first project!</span>
